# %% [markdown]
# <a href="https://colab.research.google.com/github/sangramkesharidash/Google-Colab-files/blob/main/EQUITYDATA_Screener_EDA_Using_PySpark_SQL_30_APR_2025_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('cluster').getOrCreate()
print('Spark Version: {}'.format(spark.version))
# Out:
# Spark Version: 3.5.5

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re
import os
from google.colab import drive

# Check if Google Drive is mounted; mount if not
if not os.path.exists('/content/drive'):
    drive.mount('/content/drive')
else:
    print("Google Drive already mounted.")

# Define file path and output folder
file_path = "/content/drive/My Drive/equitydata-screener-all-stocks/equitydata-screener-all-stocks-20250430.csv"
print(file_path)
# !ls -ltr $file_path
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/equitydata-screener-all-stocks/equitydata-screener-all-stocks-20250430.csv
# ls: cannot access '/content/drive/My': No such file or directory
# ls: cannot access 'Drive/equitydata-screener-all-stocks/equitydata-screener-all-stocks-20250430.csv': No such file or directory

# %%
from pyspark.sql import SparkSession

# Create a SparkSession
spark = SparkSession.builder.appName("YourAppName").getOrCreate()

# Loading the data
dataset = spark.read.csv(file_path, header=True, inferSchema=True)

# Show the data in the above file using the below command
#dataset.show(5)

# It's good practice to stop the SparkSession when you're done
# spark.stop()

# %%
from pyspark.sql import SparkSession

# Define file path (replace with your actual file path if needed)
#file_path = '/content/drive/My Drive/equitydata-screener-all-stocks/equitydata-screener-all-stocks-20250428.csv'

# Create a SparkSession
spark = SparkSession.builder.appName("IndustryPEAnalysis").getOrCreate()

# Loading the data
dataset = spark.read.csv(file_path, header=True, inferSchema=True)

# Show the first 5 rows of the data
print("First 5 rows of the dataset:")
#dataset.show(5)

# Print the schema of the DataFrame
print("Schema of the dataset:")
#dataset.printSchema()

# Register the DataFrame as a temporary SQL view
dataset.createOrReplaceTempView("equity_data")

# Execute SQL query to calculate the average Industry PE for each industry
result_df = spark.sql("""
SELECT
        Industry,
        CAST(SUM(`Market Capitalization`) AS BIGINT) as Total_Market_Capitalization_CR,
        COUNT(Name) as Total_Stocks,
        ROUND(AVG(`Industry PE`), 0) as Average_Industry_PE,
        CAST(ROUND(SUM(CASE WHEN `Price to Earning` < `Industry PE` THEN 1 ELSE 0 END) * 100 / COUNT(Name), 0) AS INT) as Percentage_Below_Industry_PE
    FROM
        equity_data
    GROUP BY
        Industry
    ORDER BY
        Total_Market_Capitalization_CR DESC
""")

# Show the result
print("\n Industry Analysis :")
result_df.show(truncate=False)

# It's good practice to stop the SparkSession when you're done
spark.stop()
# Out:
# First 5 rows of the dataset:
# Schema of the dataset:
#
#  Industry Analysis :
# +----------------------------------------------+------------------------------+------------+-------------------+----------------------------+
# |Industry                                      |Total_Market_Capitalization_CR|Total_Stocks|Average_Industry_PE|Percentage_Below_Industry_PE|
# +----------------------------------------------+------------------------------+------------+-------------------+----------------------------+
# |Finance & Investments                         |3810188                       |556         |20.0               |35                          |
# |Banks - Private Sector                        |3792444                       |29          |12.0               |52                          |
# |Computers - Software - Large                  |3051179                       |10          |30.0               |50                          |
# |Refineries                                    |2344604                       |8           |20.0               |50                          |
# |Miscellaneous                                 |2102836                       |462         |31.0               |39                          |
# |Power Generation And Supply                   |1714968                       |39          |31.0               |38                          |
# |Pharmaceuticals - Indian - Bulk Drugs & Formln|1536922                       |107         |29.0               |38                          |
# |Banks - Public Sector                         |1466864                       |12          |9.0                |58                          |
# |Telecommunications - Service Provider         |1362844                       |19          |56.0               |26                          |
# |Construction                                  |1238670                       |337         |29.0               |33                          |
# |Trading                                       |1111541                       |554         |31.0               |37                          |
# |Electric Equipment                            |1054108                       |93          |51.0               |43                          |
# |Chemicals                                     |929570                        |148         |28.0               |44                          |
# |Automobiles - Passenger Cars                  |889821                        |5           |27.0               |40                          |
# |Steel - Large                                 |824407                        |17          |17.0               |41                          |
# |Mining / Minerals / Metals                    |811690                        |62          |19.0               |37                          |
# |Cement - North India                          |713845                        |17          |46.0               |35                          |
# |Personal Care - Multinational                 |692944                        |4           |54.0               |50                          |
# |Computers - Software - Medium / Small         |690462                        |245         |32.0               |41                          |
# |Engineering - Turnkey Services                |616160                        |57          |29.0               |42                          |
# +----------------------------------------------+------------------------------+------------+-------------------+----------------------------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import col
# Create a SparkSession
spark = SparkSession.builder.appName("PSLQCalculation").getOrCreate()
# Load the data
file_path = '/content/drive/My Drive/equitydata-screener-all-stocks/equitydata-screener-all-stocks-20250428.csv' # Replace with your actual file path
dataset = spark.read.csv(file_path, header=True, inferSchema=True)
# Fill null values with 0 for Market Capitalization and Sales latest quarter
dataset = dataset.fillna(0, subset=["Market Capitalization", "Sales latest quarter"])

# Register the DataFrame as a temporary SQL view
dataset.createOrReplaceTempView("equity_data")

# Calculate PSLQ
result_df = spark.sql("""
    SELECT
        Name,
        `High price` as `52w High Rs.`,
        `Low price` as `52w Low`,
        round((`High price` - `Current Price`) / `High price` * 100, 1) as `Down %`,
        `Current Price`,
        `DMA 200`,
        `DMA 50`,
        Industry,
        `Industry PE`,
        round(`Market Capitalization` / Sales, 1) as PS_Ratio,
        round(`Market Capitalization` / (`Sales latest quarter` * 4), 1) as `PS_LastQtr`,
        round(`Sales latest quarter` / (`Profit after tax latest quarter` * 4), 1) as LastQtr_PAT_Pct
    FROM
        equity_data
    WHERE
        Industry IN ('Banks - Private Sector')

""")

# Show the first 5 rows with the PSLQ
#dataset.select("Name", "Market Capitalization", "Sales latest quarter", "PSLQ").show(5, truncate=False)

# Stop the SparkSession
#spark.stop()



# Execute SQL query to calculate the average Industry PE for each industry
result_df = spark.sql("""
    SELECT
        Name,
        `High price` as `52w High Rs.`,
        `Low price` as `52w Low`,
        round((`High price` - `Current Price`) / `High price` * 100, 1) as `Down %`,
        `Current Price`,
        `DMA 200`,
        `DMA 50`,
        Industry,
        `Industry PE`,
        round(`Market Capitalization` / Sales, 1) as PS_Ratio,
        round(`Market Capitalization` / (`Sales latest quarter` * 4), 1) as `PS_LastQtr`,
        round(`Sales latest quarter` / (`Profit after tax latest quarter` * 4), 1) as LastQtr_PAT_Pct
    FROM
        equity_data
    WHERE
        Industry IN ('Banks - Private Sector')

""")

# Industry IN ('Banks - Private Sector') AND `Current Price` < `DMA 200`

# Show the result
print("\n Industry: Banks - Private Sector")
result_df.show(truncate=False)

# It's good practice to stop the SparkSession when you're done
#spark.stop()
# Out:
#  Industry: Banks - Private Sector
# +----------------+------------+-------+------+-------------+-------+-------+----------------------+-----------+--------+----------+---------------+
# |Name            |52w High Rs.|52w Low|Down %|Current Price|DMA 200|DMA 50 |Industry              |Industry PE|PS_Ratio|PS_LastQtr|LastQtr_PAT_Pct|
# +----------------+------------+-------+------+-------------+-------+-------+----------------------+-----------+--------+----------+---------------+
# |AU Small Finance|755.4       |478.35 |8.9   |688.4        |599.91 |577.02 |Banks - Private Sector|11.9       |3.2     |3.0       |2.1            |
# |Axis Bank       |1339.65     |933.5  |11.0  |1192.8       |1097.36|1093.97|Banks - Private Sector|11.9       |2.9     |2.8       |1.1            |
# |Bandhan Bank    |222.31      |128.15 |26.1  |164.26       |168.16 |152.91 |Banks - Private Sector|11.9       |1.2     |1.2       |3.2            |
# |Capital Small   |406.7       |250.0  |25.3  |303.75       |301.85 |282.98 |Banks - Private Sector|11.9       |1.6     |1.5       |1.7            |
# |City Union Bank |187.9       |130.4  |5.0   |178.51       |164.04 |165.67 |Banks - Private Sector|11.9       |2.3     |2.2       |1.3            |
# |CSB Bank        |403.2       |266.05 |10.3  |361.85       |317.6  |317.99 |Banks - Private Sector|11.9       |1.7     |1.6       |1.3            |
# |DCB Bank        |145.95      |101.35 |4.5   |139.45       |119.1  |117.48 |Banks - Private Sector|11.9       |0.7     |0.6       |2.5            |
# |Dhanlaxmi Bank  |38.14       |22.0   |24.9  |28.65        |28.39  |27.52  |Banks - Private Sector|11.9       |0.9     |0.8       |4.2            |
# |Equitas Sma. Fin|107.8       |52.02  |37.9  |66.97        |70.12  |61.82  |Banks - Private Sector|11.9       |1.3     |1.2       |6.1            |
# |ESAF Small Fin  |64.5        |24.31  |53.3  |30.13        |39.57  |29.85  |Banks - Private Sector|11.9       |0.4     |0.4       |-1.1           |
# |Federal Bank    |217.0       |148.0  |7.9   |199.83       |187.64 |191.29 |Banks - Private Sector|11.9       |1.8     |1.7       |1.9            |
# |Fino Payments   |467.0       |180.5  |44.4  |259.59       |292.69 |246.28 |Banks - Private Sector|11.9       |11.8    |11.0      |0.5            |
# |HDFC Bank       |1978.9      |1426.8 |3.0   |1920.2       |1717.36|1797.21|Banks - Private Sector|11.9       |4.4     |4.2       |1.2            |
# |ICICI Bank      |1437.0      |1051.05|0.6   |1428.8       |1251.24|1319.46|Banks - Private Sector|11.9       |5.5     |5.3       |0.9            |
# |IDBI Bank       |107.98      |65.89  |23.4  |82.72        |79.66  |78.22  |Banks - Private Sector|11.9       |3.1     |3.2       |0.8            |
# |IDFC First Bank |84.5        |52.46  |21.3  |66.5         |65.78  |60.86  |Banks - Private Sector|11.9       |1.3     |1.3       |8.0            |
# |IndusInd Bank   |1550.0      |605.4  |46.4  |830.55       |1049.79|814.84 |Banks - Private Sector|11.9       |1.3     |1.3       |2.3            |
# |J & K Bank      |147.2       |82.01  |34.7  |96.14        |101.45 |97.25  |Banks - Private Sector|11.9       |0.9     |0.8       |1.5            |
# |Jana Small Finan|760.9       |363.8  |32.1  |516.65       |462.32 |448.69 |Banks - Private Sector|11.9       |1.2     |1.2       |2.7            |
# |Karnataka Bank  |245.0       |162.2  |17.8  |201.31       |200.05 |185.93 |Banks - Private Sector|11.9       |0.9     |0.8       |2.0            |
# +----------------+------------+-------+------+-------------+-------+-------+----------------------+-----------+--------+----------+---------------+
# only showing top 20 rows

# %%
# Execute SQL query to calculate the average Industry PE for each industry
result_df = spark.sql("""
    SELECT
        Name,
        `High price` as `52w High Rs.`,
        `Low price` as `52w Low`,
        round((`High price` - `Current Price`) / `High price` * 100, 1) as `Down %`,
        `Current Price`,
        `DMA 200`,
        `DMA 50`,
        Industry,
        `Industry PE`,
        round(`Market Capitalization` / Sales, 1) as PS_Ratio,
        round(`Market Capitalization` / (`Sales latest quarter` * 4), 1) as `PS_LastQtr`,
        round(`Sales latest quarter` / (`Profit after tax latest quarter` * 4), 1) as LastQtr_PAT_Pct
    FROM
        equity_data
    WHERE
        Industry IN ('Healthcare') AND `Current Price` < `DMA 200`

""")

# Industry IN ('Banks - Private Sector') AND `Current Price` < `DMA 200`

# Show the result
print("\n Industry: Healthcare")
result_df.show(truncate=False)

# It's good practice to stop the SparkSession when you're done
spark.stop()
# Out:
#  Industry: Healthcare
# +----------------+------------+-------+------+-------------+-------+-------+----------+-----------+--------+----------+---------------+
# |Name            |52w High Rs.|52w Low|Down %|Current Price|DMA 200|DMA 50 |Industry  |Industry PE|PS_Ratio|PS_LastQtr|LastQtr_PAT_Pct|
# +----------------+------------+-------+------+-------------+-------+-------+----------+-----------+--------+----------+---------------+
# |Aatmaj Health   |41.5        |14.5   |53.4  |19.35        |24.36  |18.28  |Healthcare|56.07      |2.8     |1.3       |6.9            |
# |Adeshwar Meditex|29.98       |15.0   |46.6  |16.0         |24.84  |21.33  |Healthcare|56.07      |0.3     |0.1       |11.4           |
# |Amkay Products  |120.96      |36.0   |60.7  |47.5         |63.22  |47.61  |Healthcare|56.07      |1.2     |0.6       |2.4            |
# |Artemis Medicare|350.0       |143.05 |24.6  |264.05       |264.85 |271.99 |Healthcare|56.07      |4.1     |4.0       |2.7            |
# |Bandaram Pharma |63.14       |28.31  |35.2  |40.91        |42.31  |44.02  |Healthcare|56.07      |1.2     |1.2       |-250.0         |
# |Broach          |52.36       |0.0    |63.7  |19.0         |34.74  |22.52  |Healthcare|56.07      |4.4     |1.6       |1.0            |
# |Chennai Meena   |59.9        |28.34  |48.1  |31.1         |37.51  |33.97  |Healthcare|56.07      |0.7     |0.7       |-3.5           |
# |Clinitech Lab   |120.75      |38.23  |62.6  |45.15        |84.43  |56.22  |Healthcare|56.07      |1.6     |0.6       |4.6            |
# |Dhanvantri Jeev.|25.2        |16.47  |20.6  |20.0         |20.4   |20.03  |Healthcare|56.07      |0.4     |0.4       |9.5            |
# |Dr Agarwal's Eye|7300.0      |2800.0 |42.4  |4207.2       |4469.1 |4373.43|Healthcare|56.07      |5.2     |5.2       |2.3            |
# |Dr Agarwal's Hea|464.0       |361.1  |18.4  |378.55       |407.85 |413.19 |Healthcare|56.07      |9.0     |6.9       |4.8            |
# |Dr Lalchand. Lab|28.9        |0.0    |60.0  |11.56        |19.24  |14.47  |Healthcare|56.07      |1.2     |0.6       |3.6            |
# |Family Care     |9.5         |3.4    |51.4  |4.62         |6.34   |4.96   |Healthcare|56.07      |2.1     |208.0     |0.0            |
# |Gian Lifecare   |26.98       |12.06  |40.8  |15.96        |18.77  |16.91  |Healthcare|56.07      |1.3     |2.1       |3.5            |
# |Global Longlife |46.44       |18.3   |48.5  |23.9         |32.07  |24.83  |Healthcare|56.07      |43.3    |NULL      |0.0            |
# |GPT Healthcare  |208.45      |126.1  |22.7  |161.08       |166.03 |156.52 |Healthcare|56.07      |3.3     |3.2       |2.1            |
# |Hemant Surgical |224.9       |88.15  |54.3  |102.75       |129.2  |107.91 |Healthcare|56.07      |1.0     |0.5       |3.8            |
# |KK Shah Hospital|59.95       |34.0   |30.1  |41.9         |50.16  |42.85  |Healthcare|56.07      |3.8     |1.8       |2.7            |
# |KMC Speciality  |95.0        |57.0   |27.1  |69.21        |75.03  |67.72  |Healthcare|56.07      |5.2     |4.6       |2.0            |
# |Krsnaa Diagnost.|1044.0      |527.55 |28.0  |751.65       |786.82 |782.14 |Healthcare|56.07      |3.6     |3.7       |1.9            |
# +----------------+------------+-------+------+-------------+-------+-------+----------+-----------+--------+----------+---------------+
# only showing top 20 rows

# %%
from pyspark.sql import SparkSession

# Define file path (replace with your actual file path if needed)
file_path = '/content/drive/My Drive/equitydata-screener-all-stocks/equitydata-screener-all-stocks-20250428.csv'

# Create a SparkSession
spark = SparkSession.builder.appName("IndustryAnalysis").getOrCreate()

# Loading the data
dataset = spark.read.csv(file_path, header=True, inferSchema=True)

# Register the DataFrame as a temporary SQL view
dataset.createOrReplaceTempView("equity_data")

# Get all unique industries
industries_df = spark.sql("SELECT DISTINCT Industry FROM equity_data")
industries = [row.Industry for row in industries_df.collect()]

# Iterate over each industry and print the analysis
for industry in industries:
    query = f"""
        SELECT
            Name,
            `High price` as `52w High Rs.`,
            `Low price` as `52w Low`,
            round((`High price` - `Current Price`) / `High price` * 100, 1) as `Down %`,
            `Current Price`,
            `DMA 200`,
            `DMA 50`,
            Industry,
            `Industry PE`,
            round(`Market Capitalization` / Sales, 1) as PS_Ratio,
            round(`Market Capitalization` / (`Sales latest quarter` * 4), 1) as `PS_LastQtr`,
            round(`Sales latest quarter` / (`Profit after tax latest quarter` * 4), 1) as LastQtr_PAT_Pct
        FROM
            equity_data
        WHERE
            Industry = '{industry}' AND `Current Price` < `DMA 200`
    """
    result_df = spark.sql(query)
    print(f"\n Industry: {industry}")
    result_df.show(truncate=False)

# It's good practice to stop the SparkSession when you're done
spark.stop()
# Out:
#  Industry: Personal Care - Multinational
# +----------------+------------+-------+------+-------------+--------+--------+-----------------------------+-----------+--------+----------+---------------+
# |Name            |52w High Rs.|52w Low|Down %|Current Price|DMA 200 |DMA 50  |Industry                     |Industry PE|PS_Ratio|PS_LastQtr|LastQtr_PAT_Pct|
# +----------------+------------+-------+------+-------------+--------+--------+-----------------------------+-----------+--------+----------+---------------+
# |Colgate-Palmoliv|3893.0      |2311.5 |30.8  |2694.5       |2744.24 |2542.34 |Personal Care - Multinational|54.06      |12.1    |12.6      |1.1            |
# |Gillette India  |10699.0     |6191.0 |24.1  |8123.0       |8359.3  |8196.21 |Personal Care - Multinational|54.06      |9.5     |9.7       |1.4            |
# |Hind. Unilever  |3035.0      |2136.0 |23.6  |2318.6       |2419.44 |2306.67 |Personal Care - Multinational|54.06      |8.6     |8.7       |1.5            |
# |P & G Hygiene   |17747.85    |12105.6|19.5  |14282.0      |14989.57|13990.83|Personal Care - Multinational|54.06      |10.7    |9.3       |1.2            |
# +----------------+------------+-------+------+-------------+--------+--------+-----------------------------+-----------+--------+----------+---------------+
#
#
#  Industry: Miscellaneous
# +----------------+------------+-------+------+-------------+-------+-------+-------------+-----------+--------+----------+---------------+
# |Name            |52w High Rs.|52w Low|Down %|Current Price|DMA 200|DMA 50 |Industry     |Industry PE|PS_Ratio|PS_LastQtr|LastQtr_PAT_Pct|
# +----------------+------------+-------+------+-------------+-------+-------+
# |Cenlub Industrie|652.0       |300.25 |46.5  |349.1        |421.52 |372.46 |Engineering|35.31      |2.2     |2.4       |2.2            |
# |CFF Fluid       |949.0       |380.05 |44.8  |523.55       |558.21 |489.47 |Engineering|78.3       |8.0     |3.2       |1.4            |
# |Chemtech Indust.|326.0       |102.3  |57.4  |138.9        |173.27 |140.06 |Engineering|35.31      |6.5     |7.6       |1.4            |
# |Concord Enviro  |860.0       |409.05 |40.1  |515.2        |683.12 |546.71 |Engineering|35.31      |2.1     |2.2       |-3.6           |
# |Cranex          |190.05      |78.7   |56.5  |82.71        |110.02 |98.6   |Engineering|35.31      |1.0     |1.2       |30.4           |
# +----------------+------------+-------+------+-------------+-------+-------+-----------+-----------+--------+----------+---------------+
# only showing top 20 rows
#
#
#  Industry: Textiles - Jute - Yarn / Products
# +---------------+------------+-------+------+-------------+-------+-------+---------------------------------+-----------+--------+----------+---------------+
# |Name           |52w High Rs.|52w Low|Down %|Current Price|DMA 200|DMA 50 |Industry                         |Industry PE|PS_Ratio|PS_LastQtr|LastQtr_PAT_Pct|
# +---------------+------------+-------+------+-------------+-------+-------+---------------------------------+-----------+--------+----------+---------------+
# |Advance Lifes. |71.43       |25.25  |58.7  |29.51        |38.06  |30.83  |Textiles - Jute - Yarn / Products|13.82      |NULL    |NULL      |0.0            |
# |AI Champ.Inds. |76.83       |37.25  |41.6  |44.9         |48.1   |43.93  |Textiles - Jute - Yarn / Products|13.82      |2.1     |1.3       |-0.3           |
# |Cheviot Company|1653.4      |973.2  |36.6  |1047.5       |1215.14|1077.53|Textiles - Jute - Yarn / Products|13.82      |1.5     |1.5       |7.9            |
# |Gloster Ltd    |940.05      |531.6  |38.6  |577.55       |681.45 |602.55 |Textiles - Jute - Yarn / Products|13.82      |1.0     |0.9       |53.5           |
# |Rajvir Inds.   |15.25       |5.98   |31.1  |10.5         |12.45  |9.46   |Textiles - Jute - Yarn / Products|13.82      |0.2     |0.2       |-0.2           |
# +---------------+------------+-------+------+-------------+-------+-------+---------------------------------+-----------+--------+----------+---------------+
#
#
#  Industry: Electrodes - Welding Equipment
# +---------------+------------+-------+------+-------------+-------+-------+------------------------------+-----------+--------+----------+---------------+
# |Name           |52w High Rs.|52w Low|Down %|Current Price|DMA 200|DMA 50 |Industry                      |Industry PE|PS_Ratio|PS_LastQtr|LastQtr_PAT_Pct|
# +---------------+------------+-------+------+-------------+-------+-------+------------------------------+-----------+--------+----------+---------------+
# |Ador Welding   |1650.0      |777.0  |45.4  |900.95       |1094.52|910.26 |Electrodes - Welding Equipment|30.8       |1.5     |1.4       |4.4            |
# |Auro Impex     |94.4        |45.65  |43.9  |52.95        |69.42  |56.29  |Electrodes - Welding Equipment|30.8       |0.3     |0.2       |8.9            |
# |Diffusion Eng  |489.96      |188.0  |50.7  |241.65       |270.02 |272.72 |Electrodes - Welding Equipment|30.8       |3.2     |3.1       |2.9            |
# |Esab India     |6999.0      |4129.75|33.6  |4645.2       |5298.12|4718.16|Electrodes - Welding Equipment|30.8       |5.3     |5.3       |2.1            |
# |Rasi Electrodes|45.24       |16.1   |58.0  |18.99        |26.7   |20.92  |Electrodes - Welding Equipment|30.8       |0.7     |0.8       |28.4           |
# +---------------+------------+-------+------+-------------+-------+-------+------------------------------+-----------+--------+----------+---------------+
#
#
#  Industry: Cement - South India
# +---------------+------------+-------+------+-------------+-------+------+--------------------+-----------+--------+----------+---------------+
# |Name           |52w High Rs.|52w Low|Down %|Current Price|DMA 200|DMA 50|Indust
# |Dr Lalchand. Lab|28.9        |0.0    |60.0  |11.56        |19.24  |14.47  |Healthcare|56.07      |1.2     |0.6       |3.6            |
# |Family Care     |9.5         |3.4    |51.4  |4.62         |6.34   |4.96   |Healthcare|56.07      |2.1     |208.0     |0.0            |
# |Gian Lifecare   |26.98       |12.06  |40.8  |15.96        |18.77  |16.91  |Healthcare|56.07      |1.3     |2.1       |3.5            |
# |Global Longlife |46.44       |18.3   |48.5  |23.9         |32.07  |24.83  |Healthcare|56.07      |43.3    |NULL      |0.0            |
# |GPT Healthcare  |208.45      |126.1  |22.7  |161.08       |166.03 |156.52 |Healthcare|56.07      |3.3     |3.2       |2.1            |
# |Hemant Surgical |224.9       |88.15  |54.3  |102.75       |129.2  |107.91 |Healthcare|56.07      |1.0     |0.5       |3.8            |
# |KK Shah Hospital|59.95       |34.0   |30.1  |41.9         |50.16  |42.85  |Healthcare|56.07      |3.8     |1.8       |2.7            |
# |KMC Speciality  |95.0        |57.0   |27.1  |69.21        |75.03  |67.72  |Healthcare|56.07      |5.2     |4.6       |2.0            |
# |Krsnaa Diagnost.|1044.0      |527.55 |28.0  |751.65       |786.82 |782.14 |Healthcare|56.07      |3.6     |3.7       |1.9            |
# +----------------+------------+-------+------+-------------+-------+-------+----------+-----------+--------+----------+---------------+
# only showing top 20 rows
#
#
#  Industry: Bearings
# +----------------+------------+-------+------+-------------+-------+-------+--------+-----------+--------+----------+---------------+
# |Name            |52w High Rs.|52w Low|Down %|Current Price|DMA 200|DMA 50 |Industry|Industry PE|PS_Ratio|PS_LastQtr|LastQtr_PAT_Pct|
# +----------------+------------+-------+------+-------------+-------+-------+--------+-----------+--------+----------+---------------+
# |Austin Engg Co  |252.0       |136.0  |38.1  |156.05       |181.44 |158.7  |Bearings|29.96      |0.5     |0.5       |7.6            |
# |Bimetal Bearings|842.8       |470.0  |30.9  |582.0        |618.04 |574.07 |Bearings|29.96      |0.9     |1.0       |4.6            |
# |Galaxy Bearings |1800.0      |601.05 |61.7  |690.0        |1021.98|741.33 |Bearings|29.96      |1.9     |3.5       |2.5            |
# |NRB Bearings    |371.0       |191.45 |39.2  |225.39       |259.79 |224.88 |Bearings|29.96      |1.9     |2.0       |2.9            |
# |NRB Indl Bearing|50.4        |19.5   |55.7  |22.31        |27.39  |23.36  |Bearings|29.96      |0.8     |0.8       |-0.7           |
# |Schaeffler India|4951.0      |2823.0 |33.6  |3287.8       |3440.19|3267.86|Bearings|29.96      |6.4     |6.2       |2.1            |
# |SKF India       |7350.0      |3541.0 |47.2  |3879.9       |4460.5 |3895.3 |Bearings|29.96      |3.9     |3.8       |2.9            |
# |SKP Bearing     |264.95      |190.0  |13.2  |230.0        |230.2  |229.75 |Bearings|29.96      |7.4     |2.8       |8.5            |
# |Timken India    |4817.9      |2200.0 |47.4  |2534.0       |3046.78|2635.58|Bearings|29.96      |6.1     |7.1       |2.3            |
# |Vishal Bearings |163.95      |78.0   |46.0  |88.61        |109.85 |90.77  |Bearings|29.96      |1.2     |1.2       |-1.8           |
# +----------------+------------+-------+------+-------------+-------+-------+--------+-----------+--------+----------+---------------+
#
#
#  Industry: Recreation / Amusement Parks
# +----------------+------------+-------+------+-------------+-------+------+----------------------------+-----------+--------+----------+---------------+
# |Name            |52w High Rs.|52w Low|Down %|Current Price|DMA 200|DMA 50|Industry                    |Industry PE|PS_Ratio|PS_LastQtr|LastQtr_PAT_Pct|
# +----------------+------------+-------+------+-------------+-------+------+----------------------------+-----------+--------+----------+---------------+
# |Delta Corp      |154.95      |76.66  |40.8  |91.67        |109.38 |90.68 |Recreation / Amusement Parks|16.51      |3.4     |3.4       |1.6            |
# |Imagica. Enter. |103.25      |57.01  |36.2  |65.92        |70.92  |66.97 |Recreation / Amusement Parks|42.29      |9.6     |9.7       |7.7            |
# |Nicco Parks     |160.0       |105.05 |24.5  |120.75       |128.83 |119.87|Recreation / Amusement Parks|42.29      |7.5     |7.5       |1.0            |
# |Wonderla Holiday|1006.55     |599.4  |30.6  |698.95       |759.17 |684.38|Recreation / Amusement Parks|42.29      |9.6     |9.1       |1.5            |
# +----------------+------------+-------+------+-------------+-------+------+----------------------------+-----------+--------+----------+---------------+
#
#
# ...
# |Bajaj Housing   |188.5       |103.0  |33.6  |125.1        |133.1  |121.61|Finance - Housing|21.62      |10.9    |10.4      |1.1            |
# |Can Fin Homes   |951.75      |558.5  |23.6  |726.95       |730.97 |675.63|Finance - Housing|21.62      |2.5     |2.4       |1.1            |
# |Coral India Fin.|77.85       |33.7   |49.1  |39.62        |46.3   |40.86 |Finance - Housing|21.62      |6.4     |10.9      |0.4            |
# |GIC Housing Fin |278.6       |151.0  |35.8  |178.88       |197.57 |176.1 |Finance - Housing|21.62      |0.9     |0.9       |1.4            |
# |Ind Bank Housing|87.9        |35.0   |54.9  |39.64        |46.16  |42.3  |Finance - Housing|21.62      |NULL    |NULL      |0.0            |
# |India Home Loans|40.0        |27.55  |18.1  |32.77        |33.47  |32.62 |Finance - Housing|21.62      |3.8     |3.5       |10.3           |
# |Reliance Home   |5.83        |2.15   |42.9  |3.33         |3.48   |3.37  |Finance - Housing|21.62      |403.8   |2019.1    |0.0            |
# |Repco Home Fin  |595.0       |307.95 |32.7  |400.35       |414.07 |365.85|Finance - Housing|21.62      |1.5     |1.4       |1.0            |
# |Sahara Housing  |57.0        |32.76  |26.6  |41.82        |41.94  |40.27 |Finance - Housing|21.62      |3.2     |3.5       |4.7            |
# |Sammaan Capital |183.55      |97.61  |32.1  |124.63       |140.81 |120.82|Finance - Housing|21.62      |1.2     |1.3       |1.7            |
# |SRG Housing     |414.65      |260.0  |24.6  |312.65       |328.51 |323.41|Finance - Housing|21.62      |3.6     |3.4       |1.7            |
# |Star Housing Fin|60.0        |27.0   |38.7  |36.81        |41.72  |35.11 |Finance - Housing|21.62      |3.6     |3.0       |2.9            |
# +----------------+------------+-------+------+-------------+-------+------+-----------------+-----------+--------+----------+---------------+
#
#
#  Industry: Oil Drilling / Allied Services
# +----------------+------------+-------+------+-------------+-------+------+------------------------------+-----------+--------+----------+---------------+
# |Name            |52w High Rs.|52w Low|Down %|Current Price|DMA 200|DMA 50|Industry                      |Industry PE|PS_Ratio|PS_LastQtr|LastQtr_PAT_Pct|
# +----------------+------------+-------+------+-------------+-------+------+------------------------------+-----------+--------+----------+---------------+
# |Aakash Explor.  |17.15       |7.3    |51.2  |8.37         |9.97   |8.67  |Oil Drilling / Allied Services|24.42      |0.8     |0.9       |22.5           |
# |Aban Offshore   |91.68       |35.32  |57.1  |39.29        |53.48  |41.41 |Oil Drilling / Allied Services|18.07      |0.5     |0.5       |-0.1           |
# |Asian Energy    |444.35      |214.85 |35.0  |288.85       |308.16 |287.85|Oil Drilling / Allied Services|18.07      |3.5     |3.5       |2.8            |
# |Dolphin Offshore|948.75      |200.0  |58.9  |390.15       |418.75 |329.28|Oil Drilling / Allied Services|24.42      |21.0    |19.0      |0.5            |
Pharmaceuticals - Indian - Bulk Drugs & Formln|29.2       |0.1     |0.1       |-0.8           |
# |Concord Biotech |2664.0      |1326.9 |41.7  |1553.3       |1806.44|1736.04|Pharmaceuticals - Indian - Bulk Drugs & Formln|29.2       |14.9    |16.6      |0.8            |
# |Concord Drugs   |44.96       |26.1   |31.5  |30.79        |35.09  |32.49  |Pharmaceuticals - Indian - Bulk Drugs & Formln|29.2       |0.6     |0.7       |11.7           |
# |Denis Chem Lab  |232.9       |87.99  |57.0  |100.09       |136.96 |108.21 |Pharmaceuticals - Indian - Bulk Drugs & Formln|29.2       |0.8     |0.8       |6.1            |
# +----------------+------------+-------+------+-------------+-------+-------+----------------------------------------------+-----------+--------+----------+---------------+
# only showing top 20 rows
#
#
#  Industry: Pharmaceuticals - Indian - Bulk Drugs
# +----------------+------------+-------+------+-------------+-------+-------+-------------------------------------+-----------+--------+----------+---------------+
# |Name            |52w High Rs.|52w Low|Down %|Current Price|DMA 200|DMA 50 |Industry                             |Industry PE|PS_Ratio|PS_LastQtr|LastQtr_PAT_Pct|
# +----------------+------------+-------+------+-------------+-------+-------+-------------------------------------+-----------+--------+----------+---------------+
# |Aarti Drugs     |635.0       |312.0  |44.6  |351.65       |429.12 |364.09 |Pharmaceuticals - Indian - Bulk Drugs|27.64      |1.5     |1.6       |3.3            |
# |Anuh Pharma     |259.15      |148.05 |33.0  |173.6        |189.52 |171.59 |Pharmaceuticals - Indian - Bulk Drugs|27.64      |1.4     |1.4       |3.9            |
# |Fermenta Biotec.|449.0       |145.0  |38.2  |277.6        |292.78 |288.93 |Pharmaceuticals - Indian - Bulk Drugs|27.64      |1.9     |1.3       |1.1            |
# |Gennex Lab.     |29.0        |11.41  |54.8  |13.12        |15.74  |13.76  |Pharmaceuticals - Indian - Bulk Drugs|27.64      |2.1     |1.9       |2.2            |
# |Godavari Drugs  |155.0       |79.0   |40.9  |91.59        |103.96 |95.52  |Pharmaceuticals - Indian - Bulk Drugs|27.64      |0.5     |0.6       |9.6            |
# |Guj. Themis Bio.|390.0       |192.35 |27.7  |282.15       |287.03 |278.11 |Pharmaceuticals - Indian - Bulk Drugs|27.64      |19.8    |19.4      |0.8            |
# |Jubilant Pharmo |1309.9      |616.85 |30.7  |907.4        |933.68 |926.35 |Pharmaceuticals - Indian - Bulk Drugs|27.64      |2.0     |2.0       |4.0            |
# |Kimia Bioscien. |58.39       |35.1   |34.0  |38.52        |45.73  |43.29  |Pharmaceuticals - Indian - Bulk Drugs|27.64      |1.6     |1.5       |1.6            |
# |Krebs Biochem   |129.07      |60.3   |39.1  |78.64        |84.49  |79.77  |Pharmaceuticals - Indian - Bulk Drugs|27.64      |3.4     |3.7       |-0.4           |
# |Lactose (India) |247.4       |84.27  |50.9  |121.38       |150.53 |123.04 |Pharmaceuticals - Indian - Bulk Drugs|27.64      |1.4     |1.5       |32.6           |
# |NGL Fine Chem   |2777.95     |957.0  |59.7  |1119.0       |1646.94|1202.53|Pharmaceuticals - Indian - Bulk Drugs|27.64      |1.8     |1.9       |17.4           |
# |Panch.Organics  |309.9       |126.0  |52.6  |146.8        |192.11 |157.04 |Pharmaceuticals - Indian - Bulk Drugs|27.64      |1.7     |1.8       |1.8            |
# |Par Drugs & Che.|348.45      |81.01  |70.4  |103.16       |181.15 |117.22 |Pharmaceuticals - Indian - Bulk Drugs|27.64      |1.3     |1.5       |9.2            |
# |Roopa Industries|114.9       |47.26  |50.9  |56.4         |65.73  |59.61  |Pharmaceuticals - Indian - Bulk Drugs|27.64      |0.4     |0.4       |10.1           |
# |Samrat Pharma   |646.0       |302.05 |41.7  |376.7        |386.4  |351.84 |Pharmaceuticals - Indian - Bulk Drugs|27.64      |0.4     |0.5       |5.7            |
# |Shelter Pharma  |69.7        |35.7   |40.7  |41.34        |49.14  |43.12  |Pharmaceuticals - Indian - Bulk Drugs|27.64      |1.1     |0.5       |1.7            |
# |Smruthi Organic |182.45      |103.0  |38.0  |113.2        |132.26 |118.66 |Pharmaceuticals - Indian - Bulk Drugs|27.64      |1.0     |1.0       |5.3            |
# |Tyche Industries|224.5       |129.1  |34.3  |147.5        |166.1  |146.7  |Pharmaceuticals - Indian - Bulk Drugs|27.64      |2.2     |2.1       |0.9            |
# +----------------+------------+-------+------+-------------+-------+-------+-------------------------------------+-----------+--------+----------+---------------+
#
#
#  Industry: Refineries
# +----------------+------------+-------+------+-------------+-------+------+----------+-----------+--------+----------+---------------+
# |Name            |52w High Rs.|52w Low|Down %|Current Price|DMA 200|DMA 50|Industry  |Industry PE|PS_Ratio|PS_LastQtr|LastQtr_PAT_Pct|
# +----------------+------------+-------+------+-------------+-------+------+----------+-----------+--------+----------+---------------+
# |C P C L         |1275.0      |433.1  |51.3  |620.95       |664.69 |589.84|Refineries|21.03      |0.2     |0.1       |9.2            |
# |Gandhar Oil Ref.|253.25      |128.3  |41.2  |149.01       |189.34 |153.33|Refineries|21.03      |0.4     |0.4       |13.0           |
# |I O C L         |185.97      |110.72 |26.6  |136.49       |138.72 |130.42|Refineries|21.03      |0.3     |0.2       |29.6           |
# |M R P L         |260.0       |98.92  |47.8  |135.66       |149.12 |131.14|Refineries|21.03      |0.3     |0.2       |16.6           |
# |Resgen          |182.85      |70.5   |54.9  |82.52        |99.64  |89.78 |Refineries|21.03      |3.1     |1.7       |1.7            |
# +----------------+------------+-------+------+-------------+-------+------+----------+-----------+--------+----------+---------------+
#
#
#  Industry: Diversified - Mega
# +-----------+------------+-------+------+-------------+-------+-------+------------------+-----------+--------+----------+---------------+
# |Name       |52w High Rs.|52w Low|Down %|Current Price|DMA 200|DMA 50 |Industry          |Industry PE|PS_Ratio|PS_LastQtr|LastQtr_PAT_Pct|
# +-----------+------------+-------+------+-------------+-------+-------+------------------+-----------+--------+----------+---------------+
# |DCM Shriram|1371.1      |884.85 |26.1  |1013.0       |1059.86|1053.47|Diversified - Mega|29.09      |1.4     |1.2       |3.2            |
# +-----------+------------+-------+------+-------------+-------+-------+------------------+-----------+--------+----------+---------------+
#
#
#  Industry: Textiles - Manmade
# +----------------+------------+-------+------+-------------+-------+------+------------------+-----------+--------+----------+---------------+
# |Name            |52w High Rs.|52w Low|Down %|Current Price|DMA 200|DMA 50|Industry          |Industry PE|PS_Ratio|PS_LastQtr|LastQtr_PAT_Pct|
# +----------------+------------+-------+------+-------------+-------+------+------------------+-----------+--------+----------+---------------+
# |Bombay Dyeing   |256.4       |117.25 |48.0  |133.41       |169.15 |140.2 |Textiles - Manmade|22.73      |1.7     |1.7       |3.2            |
# |Century Enka    |864.9       |439.95 |39.4  |524.55       |565.54 |530.95|Textiles - Manmade|22.73      |0.6     |0.6       |8.6            |
# |Filatex India   |73.39       |34.0   |40.2  |43.92        |51.2   |42.6  |Textiles - Manmade|22.73      |0.5     |0.5       |6.5            |
# |Indian Acrylics |15.55       |6.41   |47.5  |8.16         |10.16  |7.99  |Textiles - Manmade|22.73      |0.3     |0.3       |-4.9           |
# |Indo Rama Synth.|59.5        |29.1   |39.9  |35.77        |41.18  |36.8  |Textiles - Manmade|22.73      |0.2     |0.2       |21.4           |
# |Paras Petrofils |4.63        |2.11   |44.7  |2.56         |2.94   |2.69  |Textiles - Manmade|22.73      |NULL    |NULL      |0.0            |
# |Prag Bosimi Syn.|3.89        |2.21   |38.0  |2.41         |2.84   |2.62  |Textiles - Manmade|22.73      |18.1    |6.7       |-0.1           |
# |Vardhman Acrylic|69.3        |38.8   |38.1  |42.88        |50.52  |43.74 |Textiles - Manmade|22.73      |1.2     |1.1       |5.1            |
# |Vera Synthetic  |118.0       |46.8   |44.1  |66.0         |73.38  |87.69 |Textiles - Manmade|22.73      |0.8     |0.3       |4.6            |
# |Zenith Fibres   |101.67      |64.0   |28.2  |73.02        |76.96  |73.96 |Textiles - Manmade|22.73      |0.6     |0.5       |3.2            |
# +----------------+------------+-------+------+-------------+-------+------+------------------+-----------+--------+----------+---------------+
